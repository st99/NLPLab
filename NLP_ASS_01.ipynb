# %% [markdown]
# Importing required packages

# %%
# !pip install nltk
import nltk
import string
nltk.download('punkt')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %% [markdown]
# Initialising the paragraph

# %%
paragraph = "To address the challenges faced by the Indian Information Technology Industry & growth of the domestic IT Market, the Ministry of Human Resource Development (MHRD), Government of India has established twenty Indian Institutes of Information Technology (IIIT), on not-for-profit Public Private Partnership basis. As a part of this, IIIT-Surat was planned and started with initial mentoring by SVNIT, Surat till the new campus of IIIT is ready in Surat. A memorandum of understanding and a memorandum of association have been signed between the President of India, the Governor of the State of Gujarat and Industry partners namely; Gujarat Narmada Fertilizer Corporation (GNFC), Gujarat Informatics Limited (GIL) and Gujarat Gas Limited (GAL). After series of meetings at MHRD, Directorate of Technical Education (Gujarat State) and SVNIT, Surat planed various academic activities. State Government has requested Collector of Surat to allocate 50 acres of land in Surat and is in progress. B. Tech. courses in Electronics & Communication Engineering and Computer Science & Engineering have begun in SVNIT campus from July, 2017. The admission to these B.Tech., courses is conducted by Joint Seat Allocation Authority (JoSSA) from the year 2017-18 onwards. The hostel facility for the students is provided by SVNIT. The academic activities of IIIT-Surat are in time-synchronization with SVNIT."

# %% [markdown]
# Tokenizing the paragraph

# %%
words = word_tokenize(paragraph)
print(words)
# Out:
# ['To', 'address', 'the', 'challenges', 'faced', 'by', 'the', 'Indian', 'Information', 'Technology', 'Industry', '&', 'growth', 'of', 'the', 'domestic', 'IT', 'Market', ',', 'the', 'Ministry', 'of', 'Human', 'Resource', 'Development', '(', 'MHRD', ')', ',', 'Government', 'of', 'India', 'has', 'established', 'twenty', 'Indian', 'Institutes', 'of', 'Information', 'Technology', '(', 'IIIT', ')', ',', 'on', 'not-for-profit', 'Public', 'Private', 'Partnership', 'basis', '.', 'As', 'a', 'part', 'of', 'this', ',', 'IIIT-Surat', 'was', 'planned', 'and', 'started', 'with', 'initial', 'mentoring', 'by', 'SVNIT', ',', 'Surat', 'till', 'the', 'new', 'campus', 'of', 'IIIT', 'is', 'ready', 'in', 'Surat', '.', 'A', 'memorandum', 'of', 'understanding', 'and', 'a', 'memorandum', 'of', 'association', 'have', 'been', 'signed', 'between', 'the', 'President', 'of', 'India', ',', 'the', 'Governor', 'of', 'the', 'State', 'of', 'Gujarat', 'and', 'Industry', 'partners', 'namely', ';', 'Gujarat', 'Narmada', 'F
# ...

# %% [markdown]
# Removing Punctuations

# %%
only_words = [w for w in words if not w in string.punctuation]
print(only_words)
# Out:
# ['To', 'address', 'the', 'challenges', 'faced', 'by', 'the', 'Indian', 'Information', 'Technology', 'Industry', 'growth', 'of', 'the', 'domestic', 'IT', 'Market', 'the', 'Ministry', 'of', 'Human', 'Resource', 'Development', 'MHRD', 'Government', 'of', 'India', 'has', 'established', 'twenty', 'Indian', 'Institutes', 'of', 'Information', 'Technology', 'IIIT', 'on', 'not-for-profit', 'Public', 'Private', 'Partnership', 'basis', 'As', 'a', 'part', 'of', 'this', 'IIIT-Surat', 'was', 'planned', 'and', 'started', 'with', 'initial', 'mentoring', 'by', 'SVNIT', 'Surat', 'till', 'the', 'new', 'campus', 'of', 'IIIT', 'is', 'ready', 'in', 'Surat', 'A', 'memorandum', 'of', 'understanding', 'and', 'a', 'memorandum', 'of', 'association', 'have', 'been', 'signed', 'between', 'the', 'President', 'of', 'India', 'the', 'Governor', 'of', 'the', 'State', 'of', 'Gujarat', 'and', 'Industry', 'partners', 'namely', 'Gujarat', 'Narmada', 'Fertilizer', 'Corporation', 'GNFC', 'Gujarat', 'Informatics', 'Limited'
# ...

# %% [markdown]
# Removing Stopwords

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
eng_stopwords=set(stopwords.words("english"))
keywords = [w for w in only_words if not w in eng_stopwords]
print(keywords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ...

# %% [markdown]
# Lemmatizing the keywords

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
for w in keywords:
  print(wordnet_lemmatizer.lemmatize(w))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# To
# address
# challenge
# faced
# Indian
# Information
# Technology
# Industry
# growth
# domestic
# IT
# Market
# Ministry
# Human
# Resource
# Development
# MHRD
# Government
# India
# established
# twenty
# Indian
# Institutes
# Information
# Technology
# IIIT
# not-for-profit
# Public
# Private
# Partnership
# basis
# As
# part
# IIIT-Surat
# planned
# started
# initial
# mentoring
# SVNIT
# Surat
# till
# new
# campus
# IIIT
# ready
# Surat
# A
# memorandum
# understanding
# memorandum
# association
# signed
# President
# India
# Governor
# State
# Gujarat
# Industry
# partner
# namely
# Gujarat
# Narmada
# Fertilizer
# Corporation
# GNFC
# Gujarat
# Informatics
# Limited
# GIL
# Gujarat
# Gas
# Limited
# GAL
# After
# series
# meeting
# MHRD
# Directorate
# Technical
# Education
# Gujarat
# State
# SVNIT
# Surat
# planed
# various
# academic
# activity
# State
# ...

# %% [markdown]
# Stemming the keywords

# %%
from nltk.stem import PorterStemmer
porter_stemmer = PorterStemmer()
for w in keywords:
  print(porter_stemmer.stem(w))
# Out:
# To
# address
# challeng
# face
# indian
# inform
# technolog
# industri
# growth
# domest
# IT
# market
# ministri
# human
# resourc
# develop
# mhrd
# govern
# india
# establish
# twenti
# indian
# institut
# inform
# technolog
# iiit
# not-for-profit
# public
# privat
# partnership
# basi
# As
# part
# iiit-surat
# plan
# start
# initi
# mentor
# svnit
# surat
# till
# new
# campu
# iiit
# readi
# surat
# A
# memorandum
# understand
# memorandum
# associ
# sign
# presid
# india
# governor
# state
# gujarat
# industri
# partner
# name
# gujarat
# narmada
# fertil
# corpor
# gnfc
# gujarat
# informat
# limit
# gil
# gujarat
# ga
# limit
# gal
# after
# seri
# meet
# mhrd
# director
# technic
# educ
# gujarat
# state
# svnit
# surat
# plane
# variou
# academ
# activ
# state
# govern
# request
# collector
# surat
# alloc
# 50
# acr
# land
# surat
# progress
# B
# tech
# cours
# electron
# commun
# engin
# comput
# scienc
# engin
# begun
# svnit
# campu
# juli
# 2017
# the
# admiss
# ...
